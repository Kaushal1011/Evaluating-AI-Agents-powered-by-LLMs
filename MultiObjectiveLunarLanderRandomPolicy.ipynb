# %%
# !pip install  swig
# !pip install "mo-gymnasium[all]"
# Out:
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.5 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Collecting mo-gymnasium[all]
#   Downloading mo_gymnasium-1.0.1-py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.1/421.1 kB 4.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from mo-gymnasium[all])
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from mo-gymnasium[all]) (1.23.5)
# Requirement already satisfied: pygame>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from mo-gymnasium[all]) (2.5.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from mo-gymnasium[all]) (1.11.3)
# Collecting pymoo>=0.6.0 (from mo-gymnasium[all])
#   Downloading pymoo-0.6.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 15.1 MB/s eta 0:00:00
# Collecting nes-py (from mo-gymnasium[all])
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gym-super-mario-bros (from mo-gymnasium[all])
#   Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from mo-gymnasium[all]) (2.31.6)
# Collecting mujoco==2.3.2 (from mo-gymnasium[all])
#   Downloading mujoco-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 26.3 MB/s eta 0:00:00
# Collecting highway-env>=1.8 (from mo-gymnasium[all])
#   Downloading highway_env-1.8.2-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 13.6 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5 (from mo-gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 28.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.0 (from mo-gymnasium[all])
#   Downloading pygame-2.1.3.dev8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 42.0 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from mo-gymnasium[all]) (4.1.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco==2.3.2->mo-gymnasium[all]) (1.4.0)
# Collecting glfw (from mujoco==2.3.2->mo-gymnasium[all])
#   Downloading glfw-2.6.2-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco==2.3.2->mo-gymnasium[all]) (3.1.7)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->mo-gymnasium[all]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->mo-gymnasium[all]) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->mo-gymnasium[all])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from highway-env>=1.8->mo-gymnasium[all]) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from highway-env>=1.8->mo-gymnasium[all]) (1.5.3)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.14.1->mo-gymnasium[all]) (9.4.0)
# Requirement already satisfied: autograd>=1.4 in /usr/local/lib/python3.10/dist-packages (from pymoo>=0.6.0->mo-gymnasium[all]) (1.6.2)
# Collecting cma==3.2.2 (from pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading cma-3.2.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 29.2 MB/s eta 0:00:00
# Collecting alive-progress (from pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading alive_progress-3.1.4-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.4 MB/s eta 0:00:00
# Collecting dill (from pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.1 MB/s eta 0:00:00
# Collecting Deprecated (from pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: gym>=0.17.2 in /usr/local/lib/python3.10/dist-packages (from nes-py->mo-gymnasium[all]) (0.25.2)
# Collecting pyglet<=1.5.21,>=1.4.0 (from nes-py->mo-gymnasium[all])
#   Downloading pyglet-1.5.21-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 56.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from nes-py->mo-gymnasium[all]) (4.66.1)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd>=1.4->pymoo>=0.6.0->mo-gymnasium[all]) (0.18.3)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.17.2->nes-py->mo-gymnasium[all]) (0.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env>=1.8->mo-gymnasium[all]) (2.8.2)
# Collecting about-time==4.2.1 (from alive-progress->pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading about_time-4.2.1-py3-none-any.whl (13 kB)
# Collecting grapheme==0.6.0 (from alive-progress->pymoo>=0.6.0->mo-gymnasium[all])
#   Downloading grapheme-0.6.0.tar.gz (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 25.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->pymoo>=0.6.0->mo-gymnasium[all]) (1.14.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->highway-env>=1.8->mo-gymnasium[all]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->highway-env>=1.8->mo-gymnasium[all]) (1.16.0)
# Building wheels for collected packages: box2d-py, nes-py, grapheme
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373077 sha256=a96a194a15f8ed5935bd3ec7b93f731a90f8d73f23672f0648ba10fc79502dfe
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp310-cp310-linux_x86_64.whl size=535718 sha256=4f75cdea07c48264151139b5a72669eefba93154eaf0efe1a3f239dd5988429b
#   Stored in directory: /root/.cache/pip/wheels/34/a7/d5/9aa14b15df740a53d41f702e4c795731b6c4da7925deb8476c
#   Building wheel for grapheme (setup.py) ... done
#   Created wheel for grapheme: filename=grapheme-0.6.0-py3-none-any.whl size=210079 sha256=edd9d1a82ff26b6047b790294492e1293dcf3fa4644031940dda33dcd6f4f864
#   Stored in directory: /root/.cache/pip/wheels/01/e1/49/37e6bde9886439057450c494a79b0bef8bbe897a54aebfc757
# Successfully built box2d-py nes-py grapheme
# Installing collected packages: pyglet, grapheme, glfw, farama-notifications, box2d-py, pygame, mujoco, gymnasium, dill, Deprecated, cma, about-time, nes-py, alive-progress, pymoo, highway-env, gym-super-mario-bros, mo-gymnasium
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed Deprecated-1.2.14 about-time-4.2.1 alive-progress-3.1.4 box2d-py-2.3.5 cma-3.2.2 dill-0.3.7 farama-notifications-0.0.4 glfw-2.6.2 grapheme-0.6.0 gym-super-mario-bros-7.4.0 gymnasium-0.29.1 highway-env-1.8.2 mo-gymnasium-1.0.1 mujoco-2.3.2 nes-py-8.2.1 pygame-2.1.3.dev8 pyglet-1.5.21 pymoo-0.6.0.1

# %%
import gymnasium as gym
import mo_gymnasium as mo_gym
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import imageio
import matplotlib.pyplot as plt

# Initialize the MO-LunarLander environment
env = mo_gym.make(
    "mo-lunar-lander-v2",
    continuous = False,
    gravity = -10.0,
    enable_wind= False,
    wind_power = 15.0,
    turbulence_power = 1.5,
    render_mode = "rgb_array"
)

def render_to_image(env):
    """Convert the text-based rendering to an image."""
    img = env.render()
    return img

def evaluate_and_save_gif(num_episodes=100, filename="molunarlander.gif"):
    """
    Evaluate a random policy, save the rendered outputs to a GIF, and return aggregated rewards.
    """
    frames = []
    rewards = []

    for episode in range(num_episodes):
        state = env.reset()
        episode_reward = 0
        done = False

        # Add initial state to frames
        frames.append(render_to_image(env))

        while not done:
            # Choose a random action
            action = env.action_space.sample()

            # Take a step in the environment
            next_state, reward, done, _, info = env.step(action)
            episode_reward += reward

            # Add the new state to frames
            frames.append(render_to_image(env))

        rewards.append(episode_reward)

    # Save frames as a gif
    imageio.mimsave(filename, [np.array(f) for f in frames], duration=0.5)
    print(f"GIF saved as {filename}")

    return rewards

# Evaluate the random policy, save the GIF, and retrieve rewards
num_episodes = 10
rewards = evaluate_and_save_gif(num_episodes=num_episodes, filename="molunarlander.gif")

# Plotting the aggregated rewards
plt.figure(figsize=(10, 5))
plt.plot(np.arange(num_episodes), rewards, alpha=0.6)
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.title('Performance of Random Policy on mo-LunarLander over {} episodes'.format(num_episodes))
plt.show()
# Out:
# GIF saved as molunarlander.gif
